# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('data.csv',usecols=["age","sex","symptoms"])
dataset
# Out:
#        age     sex symptoms
# 0       42  female    fever
# 1       59  female    fever
# 2       38  female    cough
# 3       45    male    fever
# 4       33  female    fever
# ..     ...     ...      ...
# 466  70-79    male    fever
# 467  60-69  female    fever
# 468  60-69    male    fever
# 469  60-69    male    fever
# 470  40-49  female    fever
#
# [471 rows x 3 columns]

# %%
#dataset=dataset.set_index('age')['symptoms'].str.get_dummies(",")
dataset.info()
dataset.set_index('age')
dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471 entries, 0 to 470
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       471 non-null    object
#  1   sex       471 non-null    object
#  2   symptoms  470 non-null    object
# dtypes: object(3)
# memory usage: 11.2+ KB
#        age     sex symptoms
# 0       42  female    fever
# 1       59  female    fever
# 2       38  female    cough
# 3       45    male    fever
# 4       33  female    fever
# ..     ...     ...      ...
# 466  70-79    male    fever
# 467  60-69  female    fever
# 468  60-69    male    fever
# 469  60-69    male    fever
# 470  40-49  female    fever
#
# [471 rows x 3 columns]

# %%
#data2=dataset['sex']
#data2

# %%
#dataset=dataset.set_index('age')['symptoms'].str.get_dummies(",")
dataset
# Out:
#        age     sex symptoms
# 0       42  female    fever
# 1       59  female    fever
# 2       38  female    cough
# 3       45    male    fever
# 4       33  female    fever
# ..     ...     ...      ...
# 466  70-79    male    fever
# 467  60-69  female    fever
# 468  60-69    male    fever
# 469  60-69    male    fever
# 470  40-49  female    fever
#
# [471 rows x 3 columns]

# %%
dataset.isna().count()
# Out:
# age         471
# sex         471
# symptoms    471
# dtype: int64

# %%
print("Data types and their frequency\n{}".format(dataset.dtypes.value_counts()))
# Out:
# Data types and their frequency
# object    3
# dtype: int64

# %%
l=list(dataset.columns)
l
# Out:
# ['age', 'sex', 'symptoms']

# %%
re.sub(r"\^m\$", 'Male', 'male', flags=re.IGNORECASE)
# Out:
# 'male'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset=pd.read_csv('data.csv',usecols=["symptoms"])

import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus = []
for i in range(0, 471):
    symptoms = re.sub('[^a-zA-Z]', ' ', str(dataset['symptoms'][i]))
    symptoms = symptoms.lower()
    symptoms = symptoms.split()
    ps = PorterStemmer()
    symptoms = [ps.stem(word) for word in symptoms if not word in set(stopwords.words('english'))]
    symptoms = ' '.join(symptoms)
    corpus.append(symptoms)
x=set()
for i in corpus:
    y=i.split()
    for j in range(len(y)):
        x.add(y[j])
x=list(x)
x.sort()
print(x)
print(len(x))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADISHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['ach', 'anhel', 'asymptomat', 'bodi', 'breath', 'chest', 'condit', 'congest', 'cough', 'diarrhea', 'diarrheoa', 'diarrhoea', 'difficulti', 'discomfort', 'distress', 'dizzi', 'dri', 'dryness', 'dyspnea', 'effus', 'energi', 'expector', 'eye', 'fatigu', 'feel', 'fever', 'flu', 'full', 'gener', 'high', 'ill', 'irrit', 'joint', 'lack', 'lesion', 'like', 'limb', 'low', 'malais', 'mild', 'mouth', 'muscl', 'muscular', 'myalgia', 'nan', 'nasal', 'nausea', 'nose', 'pain', 'pharyng', 'pharyngalgia', 'pharynx', 'phlegm', 'physic', 'pleural', 'pleurit', 'pneumon', 'pneumonia', 'poor', 'problem', 'radiograph', 'respiratori', 'rever', 'rhinorrhea', 'rhinorrhoea', 'rigor', 'runni', 'sever', 'short', 'slump', 'sneez', 'sore', 'stiff', 'symptom', 'throa', 'throat', 'tight', 'walk', 'weak', 'wheez', 'ye']
# 81

# %%
from collections import defaultdict
d=defaultdict(int)
l=[]
for i in range(0, 471):
    l=str(dataset['symptoms'][i]).strip().split(',')
    print(l)
    for j in range(len(l)):
        d[l[j]]=d[l[j]]+1
    l=[]
# Out:
# ['fever']
# ['fever']
# ['cough']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['respiratory symptoms']
# ['fever']
# ['fever']
# ['fever', 'respiratory symptoms']
# ['fever', 'respiratory symptoms']
# ['fever']
# ['fever']
# ['fatigue', 'fever']
# ['discomfort', 'fever']
# ['cough', 'fever', 'muscular soreness', 'weakness']
# ['cough', 'dizziness']
# ['cough', 'fatigue', 'fever', 'weakness']
# ['cough', 'fever', 'weakness']
# ['cough', 'diarrhea', 'fever', 'rhinorrhoea', 'sneezing']
# ['anhelation', 'cough', 'fever', 'pleural effusion', 'weakness']
# ['diarrhea', 'fever', 'nasal congestion', 'pleuritic chest pain', 'sore throat']
# ['cough']
# ['cough', 'fever']
# ['cough', 'fever']
# ['fever']
# ['fever']
# ['cough', 'fever']
# ['fever']
# ['fever', 'weakness']
# ['cough', 'fever', 'muscular soreness']
# ['cough', 'fever']
# ['fever']
# ['chest distress', 'cough', 'expectoration', 'muscular soreness']
# ['cough', '']
# ['fever', 'sneeze']
# ['discomfort']
# ['cough', 'muscular stiffness', 'weakness']
# ['fever']
# ['discomfort']
# ['fever']
# ['fever']
# ['cough', 'fever']
# ['chest distress', 'dyspnea']
# ['cough', 'expectoration', 'fever']
# ['cough', 'fatigue', 'fever', '']
# ['chest tightness', 'dyspnea', 'fever']
# ['cough', 'fever']
# ['fever']
# ['fever']
# ['cough', 'fever']
# ['fever']
# ['cough', 'fever']
# ['cough', 'fever']
# ['fever', 'weakness']
# ['cough', 'fever']
# ['cough', 'fever']
# ['cough', 'fever']
# ['cough', 'fever', 'soreness']
# ['pharynx']
# ['muscular soreness']
# ['cough', 'sore throat']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fatigue', 'fever', 'weakness']
# ['cough', 'fever', 'runny nose']
# ['fever']
# ['fever']
# ['cough', 'dyspnea', 'fever']
# ['fever']
# ['fatigue', 'fever']
# ['fever', 'muscle aches', 'other symptoms']
# ['fatigue', 'muscle aches', 'sore throat']
# ['cough', 'fever']
# ['cough', 'fever']
# ['fever']
# ['fever', 'sore muscle', 'weakness']
# ['fever', 'sore muscle', 'weakness']
# ['fatigue', 'fever']
# ['cough', 'fever']
# ['runny nose', 'fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever', 'sore throat']
# ['fever', 'muscular soreness', 'rigor']
# ['diarrhea', 'dyspnea', 'lack of energy', 'muscle pain']
# ['cough', 'fever']
# ['cough', 'fatigue', 'fever']
# ['fever']
# ['fever', 'pharyngalgia']
# ['pneumonitis']
# ['pneumonia']
# ['pneumonia']
# ['fever']
# ['cough', 'discomfort', 'fever', 'other symptoms']
# ['flu-like symptoms']
# ['cough', 'fatigue', 'fever']
# ['cough', 'fever']
# ['fever', 'pneumonia', 'sore throat']
# ['cough', 'fever', 'sore throat']
# ['cough', 'fever']
# ['asymptomatic']
# ['asymptomatic']
# ['asymptomatic']
# ['cough', 'fever', 'shortness of breath']
# ['cough', 'fever']
# ['cough', 'fever']
# ['cough', 'fever']
# ['fever']
# ['cough', 'fever', 'shortness breath']
# ['fever']
# ['fever', 'sore throat']
# ['cough', 'fever', 'muscle aches']
# ['cough', 'fever', 'nausea']
# ['cough', 'fever']
# ['cough', 'fever', 'myalgia']
# ['fever']
# ['fever']
# ['fever', 'joint pain', 'pneumonia']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['cough', 'fever']
# ['fever']
# ['fever']
# ['pneumonitis']
# ['pneumonitis']
# ['pneumonitis']
# ['fever']
# ['fever']
# ['dizziness', 'sore limbs']
# ['pneumonia']
# ['cough', 'fever']
# ['fever']
# ['fever', 'runny nose']
# ['fever']
# ['fever']
# ['pneumonia']
# ['pneumonia']
# ['pneumonitis']
# ['cough', 'fever', 'myalgia', 'rhinorrhea', 'sore throat']
# ['fever', 'myalgias', 'sore throat']
# ['aching muscles', 'fever', 'pneumonia']
# ['dry cough']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['cough', 'joint pain']
# ['cough', 'fever', 'pneumonia']
# ['pneumonitis']
# ['pneumonitis']
# ['pneumonitis']
# ['pneumonitis']
# ['pneumonitis']
# ['pneumonitis']
# ['pneumonitis']
# ['pneumonitis']
# ['pneumonitis']
# ['pneumonitis']
# ['pneumonitis']
# ['myalgia', 'rhinorrhea']
# ['cough']
# ['fever']
# ['fever']
# ['fever']
# ['cough']
# ['cough', 'dyspnea']
# ['cough', 'fever']
# ['cough', 'fever']
# ['fever', 'pharyngeal discomfort']
# ['fever']
# ['fever', 'sore throat', '']
# ['cough', 'fever']
# ['fever']
# ['physical discomfort']
# ['discomfort']
# ['weakness']
# ['fever']
# ['fever']
# ['chest tightness', 'fever', 'nausea']
# ['respiratory symptoms']
# ['cough', 'fever']
# ['cough', 'sore throat']
# ['cough', 'fever']
# ['cough', 'fever', 'muscle ache']
# ['cough', 'runny nose']
# ['asymptomatic']
# ['asymptomatic']
# ['cough', 'fever']
# ['cough', 'fever']
# ['asymptomatic']
# ['runny nose']
# ['fever']
# ['cough', 'fever']
# ['cough', 'fever']
# ['fever']
# ['cough', 'fever', '']
# ['cough', 'fever']
# ['cough', 'fever']
# ['cough', '']
# ['cough', 'sore throat', '']
# ['fever']
# ['fatigue']
# ['cough']
# ['fever', 'dry cough', 'fatigue']
# ['lesions on chest radiographs']
# ['fever']
# ['fever']
# ['cough', 'fever']
# ['fever']
# ['cough', 'fever']
# ['fever']
# ['fever']
# ['chest tightness']
# ['cough', 'fever']
# ['cough', 'fever', 'runny nose']
# ['cough', 'fever', 'runny nose']
# ['cough', 'fever', 'runny nose']
# ['fever', 'sore throat']
# ['cough', 'fever']
# ['fever']
# ['fever']
# ['cough', 'fever']
# ['fever']
# ['fever']
# ['cough', 'diarrhoea', 'runny nose']
# ['cough', 'fever']
# ['cough', 'high fever', 'myalgia']
# ['fever', 'myalgia']
# ['cough']
# ['cough', 'fever']
# ['cough', 'fever', 'breathing problem']
# ['fatigue']
# ['fever', 'sore throat', 'fatigue', 'diarrhea']
# ['fever', 'fatigue']
# ['fever', 'sore throat', 'fatigue']
# ['cough']
# ['fever']
# ['chest tightness', 'fever']
# ['fever', 'joint pain', 'muscle soreness']
# ['fever']
# ['fever']
# ['fever']
# ['cough', 'fever']
# ['fever']
# ['cough', 'fever']
# ['chest pain', 'nasal congestion']
# ['cough', 'muscle soreness']
# ['cough', 'fever']
# ['fever']
# ['fever']
# ['pneumonitis']
# ['fever', 'myalgia', 'shortness of breath']
# ['cough', 'fever']
# ['fever']
# ['fever']
# ['fever']
# ['cough', 'fever', 'pneumonia', 'respiratory distress']
# ['fever', 'runny nose']
# ['cough', 'fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever', 'runny nose', 'sore throat', 'wheezing']
# ['cough', 'respiratory problems']
# ['nausea']
# ['fever', '']
# ['fever']
# ['fever', 'full body slump']
# ['cough', 'fever']
# ['cough', 'fever']
# ['fever', 'cough']
# ['fever', 'cough']
# ['fever', 'dry throat', 'sore throat']
# ['fever', 'runny nose']
# ['dry throat']
# ['', 'dry mouth']
# ['fever', 'dry mouth', 'throat discomfort']
# ['fever']
# ['pharyngeal discomfort']
# ['fever']
# ['diarrhea']
# ['cough', 'throat discomfort']
# ['Pharyngeal dryness']
# ['cough', 'fever']
# ['fever']
# ['dry throat', 'dry cough']
# ['chest pain', 'cough']
# ['cough', 'chest tightness', 'dry mouth']
# ['cough', 'fever']
# ['fever']
# ['fever']
# ['fever']
# ['cough', 'fever']
# ['cough', 'fever']
# ['cough', 'fever']
# ['cough', 'fever', 'sore throat']
# ['fever']
# ['cough', 'diarrheoa']
# ['cough', 'fever']
# ['fever']
# ['cough', 'fever']
# ['cough', 'fatigue', 'fever']
# ['fever', 'severe pneumonia']
# ['eye irritation', 'fever']
# ['fever']
# ['cough', 'fever', 'sore throat']
# ['cough', 'fever']
# ['dyspnea', 'fever']
# ['cough', 'difficulty breathing', 'fever']
# ['fever']
# ['fever', 'runny nose']
# ['cough', 'runny nose']
# ['fatigue']
# ['fever']
# ['mild cough']
# ['cough']
# ['cough']
# ['Sore throat']
# ['cough']
# ['fever']
# ['feeling ill', 'cough']
# ['cough', 'fever']
# ['cough', 'fever']
# ['fatigue']
# ['diarrhea', 'fever', 'general malaise']
# ['fever']
# ['cough', 'fever', 'malaise']
# ['fever']
# ['poor physical condition']
# ['cough', 'fatigue', 'fever']
# ['cough', 'shortness of breath']
# ['cough', 'fever']
# ['fever']
# ['fever']
# ['yes']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['nan']
# ['nausea', 'cough', 'pneumonia', 'fever']
# ['fever']
# ['fever', 'cough']
# ['fever']
# ['fever']
# ['malaise', '']
# ['fever', 'breathing difficulty']
# ['fever', 'cough', 'malaise']
# ['sore throat', 'Cough', 'fever']
# ['difficulty breathing']
# ['fever']
# ['fever', 'shortness of breath', 'pneumonia']
# ['severe dyspnea']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever', 'cough']
# ['nausea']
# ['fever']
# ['fever']
# ['chest tightness']
# ['cough']
# ['fever']
# ['fever 39.3']
# ['fever 38']
# ['fever 38']
# ['fever', 'cough']
# ['fever']
# ['fever']
# ['cough']
# ['dry cough']
# ['cough']
# ['fever']
# ['flu-like symptoms']
# ['sore throat']
# ['fever', 'sore throat', 'mild cough']
# ['fever']
# ['cough']
# ['fever']
# ['fever', 'cough']
# ['cough']
# ['cough']
# ['low fever']
# ['low fever']
# ['low fever']
# ['fever', 'malaise']
# ['sore throat', 'fever']
# ['fever', 'pneumonia']
# ['fever', 'cough']
# ['fever', 'malaise']
# ['fever', 'cough']
# ['fever Cough', 'malaise', '']
# ['cough', 'sore throat', 'chest pain']
# ['fever', 'cough', 'phlegm', 'dyspnea']
# ['fever', 'cough', 'phlegm', 'dyspnea']
# ['fever', 'cough', 'phlegm']
# ['fever', 'sore throat']
# ['fever']
# ['rever', 'cough']
# ['fever', 'cough']
# ['fever', 'cough']
# ['malaise', 'fever', 'pneumonia']
# ['Sore throat']
# ['fever']
# ['fever', 'malaise']
# ['fever', 'cough', 'phlegm']
# ['Fever', 'cough', '']
# ['fever']
# ['cough', 'malaise']
# ['sore throat', 'fever']
# ['fatigue', 'fever']
# ['fever']
# ['cough', 'fever', 'sore throat']
# ['fever', 'joint pain']
# ['fever', 'cough']
# ['fever', 'malaise', 'joint pain']
# ['fever', 'cough']
# ['fever', 'cough']
# ['cough', 'fever', 'joint pain']
# ['Cough', 'fever']
# ['Fever', 'malaise', 'sore throa']
# ['cough', 'sore throat']
# ['Fever']
# ['Fever', 'cough', '.']
# ['fatigue']
# ['fever']
# ['cough', 'sore throat']
# ['cough', 'phlegm', 'fever']
# ['fever']
# ['fever', 'fatigue', 'difficulty walking']
# ['cough']
# ['fever']
# ['fever', 'malaise']
# ['cough', 'fever', 'cough', 'breathing difficulty']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']
# ['fever']

# %%
print(d)
# Out:
# defaultdict(<class 'int'>, {'fever': 342, 'cough': 165, 'respiratory symptoms': 4, 'fatigue': 22, 'discomfort': 5, 'muscular soreness': 5, 'weakness': 11, 'dizziness': 2, 'diarrhea': 6, 'rhinorrhoea': 1, 'sneezing': 1, 'anhelation': 1, 'pleural effusion': 1, 'nasal congestion': 2, 'pleuritic chest pain': 1, 'sore throat': 29, 'chest distress': 2, 'expectoration': 2, '': 11, 'sneeze': 1, 'muscular stiffness': 1, 'dyspnea': 8, 'chest tightness': 6, 'soreness': 1, 'pharynx': 1, 'runny nose': 14, 'muscle aches': 3, 'other symptoms': 2, 'sore muscle': 2, 'rigor': 1, 'lack of energy': 1, 'muscle pain': 1, 'pharyngalgia': 1, 'pneumonitis': 17, 'pneumonia': 14, 'flu-like symptoms': 2, 'asymptomatic': 6, 'shortness of breath': 4, 'shortness breath': 1, 'nausea': 5, 'myalgia': 6, 'joint pain': 6, 'sore limbs': 1, 'rhinorrhea': 2, 'myalgias': 1, 'aching muscles': 1, 'dry cough': 4, 'pharyngeal discomfort': 2, 'physical discomfort': 1, 'muscle ache': 1, 'lesions on chest radiographs': 1, 'diarrhoea': 1, 'high fever': 1, 'breathing problem': 1, 'muscle soreness': 2, 'chest pain': 3, 'respiratory distress': 1, 'wheezing': 1, 'respiratory problems': 1, 'full body slump': 1, 'dry throat': 3, 'dry mouth': 3, 'throat discomfort': 2, 'Pharyngeal dryness': 1, 'diarrheoa': 1, 'severe pneumonia': 1, 'eye irritation': 1, 'difficulty breathing': 2, 'mild cough': 2, 'Sore throat': 2, 'feeling ill': 1, 'general malaise': 1, 'malaise': 12, 'poor physical condition': 1, 'yes': 1, 'nan': 1, 'breathing difficulty': 2, 'Cough': 2, 'severe dyspnea': 1, 'fever 39.3': 1, 'fever 38': 2, 'low fever': 3, 'fever Cough': 1, 'phlegm': 5, 'rever': 1, 'Fever': 4, 'sore throa': 1, '.': 1, 'difficulty walking': 1})

# %%
for i in d:
    d[i]=d[i]/471

# %%
print(d)
# Out:
# defaultdict(<class 'int'>, {'fever': 0.7261146496815286, 'cough': 0.3503184713375796, 'respiratory symptoms': 0.008492569002123142, 'fatigue': 0.04670912951167728, 'discomfort': 0.010615711252653927, 'muscular soreness': 0.010615711252653927, 'weakness': 0.02335456475583864, 'dizziness': 0.004246284501061571, 'diarrhea': 0.012738853503184714, 'rhinorrhoea': 0.0021231422505307855, 'sneezing': 0.0021231422505307855, 'anhelation': 0.0021231422505307855, 'pleural effusion': 0.0021231422505307855, 'nasal congestion': 0.004246284501061571, 'pleuritic chest pain': 0.0021231422505307855, 'sore throat': 0.06157112526539278, 'chest distress': 0.004246284501061571, 'expectoration': 0.004246284501061571, '': 0.02335456475583864, 'sneeze': 0.0021231422505307855, 'muscular stiffness': 0.0021231422505307855, 'dyspnea': 0.016985138004246284, 'chest tightness': 0.012738853503184714, 'soreness': 0.0021231422505307855, 'pharynx': 0.0021231422505307855, 'runny nose': 0.029723991507430998, 'muscle aches': 0.006369426751592357, 'other symptoms': 0.004246284501061571, 'sore muscle': 0.004246284501061571, 'rigor': 0.0021231422505307855, 'lack of energy': 0.0021231422505307855, 'muscle pain': 0.0021231422505307855, 'pharyngalgia': 0.0021231422505307855, 'pneumonitis': 0.036093418259023353, 'pneumonia': 0.029723991507430998, 'flu-like symptoms': 0.004246284501061571, 'asymptomatic': 0.012738853503184714, 'shortness of breath': 0.008492569002123142, 'shortness breath': 0.0021231422505307855, 'nausea': 0.010615711252653927, 'myalgia': 0.012738853503184714, 'joint pain': 0.012738853503184714, 'sore limbs': 0.0021231422505307855, 'rhinorrhea': 0.004246284501061571, 'myalgias': 0.0021231422505307855, 'aching muscles': 0.0021231422505307855, 'dry cough': 0.008492569002123142, 'pharyngeal discomfort': 0.004246284501061571, 'physical discomfort': 0.0021231422505307855, 'muscle ache': 0.0021231422505307855, 'lesions on chest radiographs': 0.0021231422505307855, 'diarrhoea': 0.0021231422505307855, 'high fever': 0.0021231422505307855, 'breathing problem': 0.0021231422505307855, 'muscle soreness': 0.004246284501061571, 'chest pain': 0.006369426751592357, 'respiratory distress': 0.0021231422505307855, 'wheezing': 0.0021231422505307855, 'respiratory problems': 0.0021231422505307855, 'full body slump': 0.0021231422505307855, 'dry throat': 0.006369426751592357, 'dry mouth': 0.006369426751592357, 'throat discomfort': 0.004246284501061571, 'Pharyngeal dryness': 0.0021231422505307855, 'diarrheoa': 0.0021231422505307855, 'severe pneumonia': 0.0021231422505307855, 'eye irritation': 0.0021231422505307855, 'difficulty breathing': 0.004246284501061571, 'mild cough': 0.004246284501061571, 'Sore throat': 0.004246284501061571, 'feeling ill': 0.0021231422505307855, 'general malaise': 0.0021231422505307855, 'malaise': 0.025477707006369428, 'poor physical condition': 0.0021231422505307855, 'yes': 0.0021231422505307855, 'nan': 0.0021231422505307855, 'breathing difficulty': 0.004246284501061571, 'Cough': 0.004246284501061571, 'severe dyspnea': 0.0021231422505307855, 'fever 39.3': 0.0021231422505307855, 'fever 38': 0.004246284501061571, 'low fever': 0.006369426751592357, 'fever Cough': 0.0021231422505307855, 'phlegm': 0.010615711252653927, 'rever': 0.0021231422505307855, 'Fever': 0.008492569002123142, 'sore throa': 0.0021231422505307855, '.': 0.0021231422505307855, 'difficulty walking': 0.0021231422505307855})
